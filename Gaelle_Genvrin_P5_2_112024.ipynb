# %% [markdown]
# **Gaelle_Genvrin_P_5_2_112024**<br>
#
# **Objectif du script**<br>
#
# Dans la cellule ci-bas, nous allons tester l’API de Stack Exchange via le wrapper Python StackAPI, afin de vérifier sa pertinence et la qualité de sa documentation.<br>
# L’objectif est de récupérer 50 questions issues de Stack Overflow, postées entre janvier 2022 et aujourd’hui, ayant le tag python et un score strictement supérieur à 50 votes.<br>
# Les données principales (titre, date, tags et score) seront extraites dans un DataFrame Pandas pour faciliter leur consultation et évaluation.<br>
#
# **Considérations RGPD** <br>
#
# Conformément aux principes du RGPD (Règlement Général sur la Protection des Données), seules les informations strictement nécessaires au projet sont récupérées :<br>
# Pas de données personnelles (nom, identifiant, profil de l’auteur, etc.)<br>
# Uniquement des données anonymisées et publiques : date de création, titre de la question, tags associés et score (nombre de votes)<br>
# Aucune donnée ne permet d’identifier un utilisateur de la plateforme. L’usage de l’API respecte donc les exigences en matière de protection de la vie privée.<br>

# %%
pip install stackapi
# on a installé la bibliothèque dédiée
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting stackapi
#   Using cached StackAPI-0.3.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: requests in c:\users\ggenv\appdata\roaming\python\python39\site-packages (from stackapi) (2.32.3)
# Requirement already satisfied: six in c:\users\ggenv\appdata\roaming\python\python39\site-packages (from stackapi) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ggenv\appdata\roaming\python\python39\site-packages (from requests->stackapi) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ggenv\appdata\roaming\python\python39\site-packages (from requests->stackapi) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ggenv\appdata\roaming\python\python39\site-packages (from requests->stackapi) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ggenv\appdata\roaming\python\python39\site-packages (from requests->stackapi) (2025.1.31)
# Using cached StackAPI-0.3.1-py3-none-any.whl (7.2 kB)
# Installing collected packages: stackapi
# Successfully installed stackapi-0.3.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from stackapi import StackAPI
import pandas as pd
import datetime

# Connexion à l'API Stack Overflow
SITE = StackAPI('stackoverflow')

# Définition des dates (période large)
from_date = int(datetime.datetime(2022, 1, 1).timestamp())  # à partir du 1°° janvier 2022
to_date = int(datetime.datetime.now().timestamp())  # Date actuelle

# Définir page_size et max_pages pour limiter la récupération à 50 questions
SITE.page_size = 50  # Nombre de résultats par page
SITE.max_pages = 1   # Une seule page pour récupérer les 50 questions d'un ocup

# Récupération des questions (EXACTEMENT 50 comme vu plus haut)
questions = SITE.fetch(
    'questions',
    fromdate=from_date,
    todate=to_date,
    min=50,  # Score minimum de 50 votes
    tagged='python',
    sort='votes'
)

# Vérification du nombre de questions récupérées
print(f"Nombre de questions récupérées: {len(questions['items'])}")

# Extraction des données principales
data10 = [
    {
        'date': datetime.datetime.utcfromtimestamp(q['creation_date']).strftime('%Y-%m-%d'),
        'titre': q['title'],
        'tags': ', '.join(q['tags']),
        'score': q['score']
    }
    for q in questions['items']
]

# Création du DataFrame
df10 = pd.DataFrame(data10)

# Affichage du DataFrame
print(df10)
# Out:
# Nombre de questions récupérées: 50
#           date                                              titre  \
# 0   2023-03-01  How do I solve &quot;error: externally-managed...
# 1   2023-04-07  Error &quot;&#39;DataFrame&#39; object has no ...
# 2   2022-03-23  How can I fix the &quot;zsh: command not found...
# 3   2023-10-26  AttributeError: module &#39;pkgutil&#39; has n...
# 4   2022-05-31  TypeError: Descriptors cannot not be created d...
# 5   2022-01-25          Does it make sense to use Conda + Poetry?
# 6   2023-10-02  Why did Flask start failing with &quot;ImportE...
# 7   2022-09-23  AttributeError: module &#39;lib&#39; has no at...
# 8   2022-03-30  ImportError: cannot import name &#39;_unicodef...
# 9   2022-01-24  Good alternative to Pandas .append() method, n...
# 10  2023-05-06  ImportError: urllib3 v2.0 only supports OpenSS...
# 11  2023-03-31  OpenAI API error 429: &quot;You exceeded your ...
# 12  2024-06-17  numpy.dtype size changed, may indicate binary ...
# 13  2023-03-01  pip install -r requirements.txt is failing: &q...
# 14  2022-04-17                 How to use python typing.Annotated
# 15  2022-05-10  ImportError: cannot import name &#39;soft_unic...
# 16  2022-05-05  libssl.so.1.1: cannot open shared object file:...
# 17  2022-04-02  ImportError: cannot import name &#39;escape&#3...
# 18  2022-06-27  Selenium - Python - AttributeError: &#39;WebDr...
# 19  2023-07-04  AttributeError: module &#39;PIL.Image&#39; has...
# 20  2022-05-30  There was an error checking the latest version...
# 21  2022-02-18  Unable to restore Visual Studio 2022 window (I...
# 22  2022-03-17  FastAPI runs API calls in serial instead of pa...
# 23  2022-06-10  If Python strings are immutable, why does it k...
# 24  2023-01-02  Error Updating Python3 pip AttributeError: mod...
# 25  2022-01-27                           Can we make 1 == 2 true?
# 26  2022-05-08  What is the difference between type-hinting a ...
# 27  2022-09-04  How to reference a requirements.txt in the pyp...
# 28  2023-02-18  Error: Unable to extract uploader id - Youtube...
# 29  2022-05-18  Multiple top-level packages discovered in a fl...
# 30  2022-01-16  What&#39;s the mathematical reason behind Pyth...
# 31  2023-03-21  OpenAI API: How do I count tokens before(!) I ...
# 32  2022-02-01  AttributeError: module &#39;collections&#39; h...
# 33  2024-03-08  Logging Error: Failed to initialize logging sy...
# 34  2023-02-09  Poetry install on an existing project Error &q...
# 35  2022-07-13  What is the proper way to install TensorFlow o...
# 36  2022-03-24     SSL error unsafe legacy renegotiation disabled
# 37  2023-01-28  pre-commit fails to install isort 5.11.4 with ...
# 38  2022-06-13  How to convert Python dataclass to dictionary ...
# 39  2022-11-20  Is requirements.txt still needed when using py...
# 40  2022-03-28  Why is it faster to compare strings that match...
# 41  2022-10-02  &#39;EntryPoints&#39; object has no attribute ...
# 42  2024-08-19  VSCode Python extension loading forever, sayin...
# 43  2022-05-31       f-string representation different than str()
# 44  2022-12-18  How can I solve error &quot;module &#39;numpy&...
# 45  2022-04-01  ERROR: Could not build wheels for backports.zo...
# 46  2022-02-13  in ipython how do I accept and use an autocomp...
# 47  2022-12-22  How to solve AttributeError: module &#39;numpy...
# 48  2022-02-19  ImportError: cannot import name &#39;json&#39;...
# 49  2022-04-05  ImportError: cannot import name &#39;builder&#...
#
#                                                  tags  score
# 0            python, pip, debian, failed-installation    908
# 1   python, pandas, dataframe, concatenation, attr...    321
# 2   python, macos, terminal, atom-editor, macos-mo...    267
# 3                      python, python-3.x, numpy, pip    227
# 4                             python, tensorflow, ray    224
# 5   python, machine-learning, package, conda, pyth...    203
# 6                     python, flask, pytest, werkzeug    201
# 7                        python, google-analytics-api    194
# 8                                python, python-black    184
# 9   python, pandas, dataframe, data-wrangling, dat...    182
# 10                        python, openai-api, urllib3    177
# 11  python, prompt, openai-api, completion, chatgp...    177
# 12                       python, numpy, matlab, spacy    172
# 13                                      python, linux    169
# 14                              python, python-typing    154
# 15  python, docker, docker-compose, dependencies, ...    143
# 16              python, linux, openssl, python-poetry    142
# 17            python, compiler-errors, jinja2, pydash    136
# 18  python, selenium, google-chrome, selenium-webd...    135
# 19                     python, python-imaging-library    122
# 20                                        python, pip    108
# 21                python, windows, visual-studio-2022    107
# 22  python, asynchronous, concurrency, python-asyn...    105
# 23  python, string, reference, immutability, strin...    103
# 24   python, ubuntu, pip, windows-subsystem-for-linux    102
# 25                  python, cpython, python-internals    101
# 26                              python, python-typing     98
# 27            python, pip, setuptools, pyproject.toml     95
# 28                python, ffmpeg, discord, youtube-dl     94
# 29                              python, python-poetry     92
# 30  python, c++, python-3.x, rounding, integer-div...     88
# 31      python, openai-api, chatgpt-api, gpt-3, gpt-4     88
# 32                            python, python-3.x, pip     87
# 33                               python, swift, xcode     86
# 34                              python, python-poetry     84
# 35                python, tensorflow, conda, apple-m1     84
# 36                python, ssl, openssl, runtime-error     83
# 37          python, pre-commit, pre-commit.com, isort     81
# 38       python, json, dictionary, python-dataclasses     81
# 39  python, python-packaging, requirements.txt, py...     79
# 40                    python, performance, comparison     77
# 41                      python, django, digital-ocean     76
# 42                         python, visual-studio-code     75
# 43                            python, enums, f-string     75
# 44                                      python, numpy     75
# 45                             python, django, heroku     73
# 46                                    python, ipython     72
# 47          python, python-3.x, numpy, attributeerror     71
# 48              python, docker, flask, docker-compose     71
# 49                                             python     70

# %% [markdown]
# **Conclusion sur l’utilisation de l’API StackExchange** <br>
# L’utilisation du wrapper Python StackAPI s’est révélée simple et efficace pour interroger l’API Stack Exchange.<br>
# La documentation est claire, et l’extraction des données se fait rapidement avec une syntaxe accessible. Les données récupérées répondent bien aux critères définis (tag python, score > 50, période donnée).<br>
# L’ensemble du processus respecte les contraintes du projet et les exigences du RGPD, en ne collectant que des informations anonymes et strictement nécessaires.<br>
#
# **Cette approche pourra donc être utilisée ou répliquée dans un cadre plus large si besoin, notamment pour enrichir un corpus ou explorer des tendances autour d’un langage donné comme Python.**
