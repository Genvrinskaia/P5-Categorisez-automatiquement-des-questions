# %%
pip install stackapi
# Out:
# Collecting stackapi
#   Downloading StackAPI-0.3.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: requests in c:\users\ggenv\appdata\local\programs\python\python312\lib\site-packages (from stackapi) (2.32.3)
# Requirement already satisfied: six in c:\users\ggenv\appdata\local\programs\python\python312\lib\site-packages (from stackapi) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ggenv\appdata\local\programs\python\python312\lib\site-packages (from requests->stackapi) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ggenv\appdata\local\programs\python\python312\lib\site-packages (from requests->stackapi) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ggenv\appdata\local\programs\python\python312\lib\site-packages (from requests->stackapi) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ggenv\appdata\local\programs\python\python312\lib\site-packages (from requests->stackapi) (2025.1.31)
# Downloading StackAPI-0.3.1-py3-none-any.whl (7.2 kB)
# Installing collected packages: stackapi
# Successfully installed stackapi-0.3.1
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution ~otebook (C:\Users\ggenv\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~otebook (C:\Users\ggenv\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~otebook (C:\Users\ggenv\AppData\Local\Programs\Python\Python312\Lib\site-packages)

# %%
from stackapi import StackAPI
import pandas as pd
import datetime

# Connexion à l'API Stack Overflow
SITE = StackAPI('stackoverflow')

# Définition des dates (période large)
from_date = int(datetime.datetime(2022, 1, 1).timestamp())  # 1er janvier 2008
to_date = int(datetime.datetime.now().timestamp())  # Date actuelle

# Définir page_size et max_pages pour limiter la récupération à 50 questions
SITE.page_size = 50  # Nombre de résultats par page
SITE.max_pages = 1   # Une seule page pour récupérer les 50 questions d'un ocup

# Récupération des questions (EXACTEMENT 50 comme vu plus haut)
questions = SITE.fetch(
    'questions',
    fromdate=from_date,
    todate=to_date,
    min=50,  # Score minimum de 50 votes
    tagged='python',
    sort='votes'
)

# Vérification du nombre de questions récupérées
print(f"Nombre de questions récupérées: {len(questions['items'])}")

# Extraction des données principales
data = [
    {
        'date': datetime.datetime.utcfromtimestamp(q['creation_date']).strftime('%Y-%m-%d'),
        'titre': q['title'],
        'tags': ', '.join(q['tags']),
        'score': q['score']
    }
    for q in questions['items']
]

# Création du DataFrame
df = pd.DataFrame(data)

# Affichage du DataFrame
print(df)
# Out:
# Nombre de questions récupérées: 50
#           date                                              titre  \
# 0   2023-03-01  How do I solve &quot;error: externally-managed...
# 1   2023-04-07  Error &quot;&#39;DataFrame&#39; object has no ...
# 2   2022-03-23  How can I fix the &quot;zsh: command not found...
# 3   2022-05-31  TypeError: Descriptors cannot not be created d...
# 4   2023-10-26  AttributeError: module &#39;pkgutil&#39; has n...
# 5   2023-10-02  Why did Flask start failing with &quot;ImportE...
# 6   2022-01-25          Does it make sense to use Conda + Poetry?
# 7   2022-09-23  AttributeError: module &#39;lib&#39; has no at...
# 8   2022-03-30  ImportError: cannot import name &#39;_unicodef...
# 9   2022-01-24  Good alternative to Pandas .append() method, n...
# 10  2023-05-06  ImportError: urllib3 v2.0 only supports OpenSS...
# 11  2023-03-31  OpenAI API error 429: &quot;You exceeded your ...
# 12  2023-03-01  pip install -r requirements.txt is failing: &q...
# 13  2024-06-17  numpy.dtype size changed, may indicate binary ...
# 14  2022-04-17                 How to use python typing.Annotated
# 15  2022-05-10  ImportError: cannot import name &#39;soft_unic...
# 16  2022-05-05  libssl.so.1.1: cannot open shared object file:...
# 17  2022-04-02  ImportError: cannot import name &#39;escape&#3...
# 18  2022-06-27  Selenium - Python - AttributeError: &#39;WebDr...
# 19  2023-07-04  AttributeError: module &#39;PIL.Image&#39; has...
# 20  2022-05-30  There was an error checking the latest version...
# 21  2022-02-18  Unable to restore Visual Studio 2022 window (I...
# 22  2022-06-10  If Python strings are immutable, why does it k...
# 23  2023-01-02  Error Updating Python3 pip AttributeError: mod...
# 24  2022-01-27                           Can we make 1 == 2 true?
# 25  2022-03-17  FastAPI runs API calls in serial instead of pa...
# 26  2022-05-08  What is the difference between type-hinting a ...
# 27  2023-02-18  Error: Unable to extract uploader id - Youtube...
# 28  2022-09-04  How to reference a requirements.txt in the pyp...
# 29  2022-05-18  Multiple top-level packages discovered in a fl...
# 30  2022-01-16  What&#39;s the mathematical reason behind Pyth...
# 31  2022-02-01  AttributeError: module &#39;collections&#39; h...
# 32  2023-03-21  OpenAI API: How do I count tokens before(!) I ...
# 33  2024-03-08  Logging Error: Failed to initialize logging sy...
# 34  2023-02-09  Poetry install on an existing project Error &q...
# 35  2022-03-24     SSL error unsafe legacy renegotiation disabled
# 36  2022-07-13  What is the proper way to install TensorFlow o...
# 37  2023-01-28  pre-commit fails to install isort 5.11.4 with ...
# 38  2022-06-13  How to convert Python dataclass to dictionary ...
# 39  2022-11-20  Is requirements.txt still needed when using py...
# 40  2022-03-28  Why is it faster to compare strings that match...
# 41  2022-10-02  &#39;EntryPoints&#39; object has no attribute ...
# 42  2022-12-18  How can I solve error &quot;module &#39;numpy&...
# 43  2022-05-31       f-string representation different than str()
# 44  2022-04-01  ERROR: Could not build wheels for backports.zo...
# 45  2022-02-13  in ipython how do I accept and use an autocomp...
# 46  2022-02-19  ImportError: cannot import name &#39;json&#39;...
# 47  2022-12-22  How to solve AttributeError: module &#39;numpy...
# 48  2022-04-05  ImportError: cannot import name &#39;builder&#...
# 49  2023-06-06  &quot;cannot import name &#39;DEFAULT_CIPHERS&...
#
#                                                  tags  score
# 0            python, pip, debian, failed-installation    877
# 1   python, pandas, dataframe, concatenation, attr...    317
# 2   python, macos, terminal, atom-editor, macos-mo...    266
# 3                             python, tensorflow, ray    223
# 4                      python, python-3.x, numpy, pip    218
# 5                     python, flask, pytest, werkzeug    201
# 6   python, machine-learning, package, conda, pyth...    200
# 7                        python, google-analytics-api    190
# 8                                python, python-black    184
# 9   python, pandas, dataframe, data-wrangling, dat...    182
# 10                        python, openai-api, urllib3    174
# 11  python, prompt, openai-api, completion, chatgp...    174
# 12                                      python, linux    165
# 13                       python, numpy, matlab, spacy    156
# 14                              python, python-typing    146
# 15  python, docker, docker-compose, dependencies, ...    143
# 16              python, linux, openssl, python-poetry    141
# 17            python, compiler-errors, jinja2, pydash    136
# 18  python, selenium, google-chrome, selenium-webd...    135
# 19                     python, python-imaging-library    120
# 20                                        python, pip    107
# 21                python, windows, visual-studio-2022    107
# 22  python, string, reference, immutability, strin...    103
# 23   python, ubuntu, pip, windows-subsystem-for-linux    102
# 24                  python, cpython, python-internals    101
# 25  python, asynchronous, concurrency, python-asyn...     99
# 26                              python, python-typing     96
# 27                python, ffmpeg, discord, youtube-dl     94
# 28            python, pip, setuptools, pyproject.toml     92
# 29                              python, python-poetry     90
# 30  python, c++, python-3.x, rounding, integer-div...     88
# 31                            python, python-3.x, pip     87
# 32      python, openai-api, chatgpt-api, gpt-3, gpt-4     87
# 33                               python, swift, xcode     86
# 34                              python, python-poetry     84
# 35                python, ssl, openssl, runtime-error     83
# 36                python, tensorflow, conda, apple-m1     83
# 37          python, pre-commit, pre-commit.com, isort     81
# 38       python, json, dictionary, python-dataclasses     81
# 39  python, python-packaging, requirements.txt, py...     79
# 40                    python, performance, comparison     77
# 41                      python, django, digital-ocean     76
# 42                                      python, numpy     75
# 43                            python, enums, f-string     74
# 44                             python, django, heroku     73
# 45                                    python, ipython     72
# 46              python, docker, flask, docker-compose     71
# 47          python, python-3.x, numpy, attributeerror     70
# 48                                             python     69
# 49  python, amazon-web-services, amazon-s3, aws-la...     69
# C:\Users\ggenv\AppData\Local\Temp\ipykernel_15204\2788500937.py:32: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   'date': datetime.datetime.utcfromtimestamp(q['creation_date']).strftime('%Y-%m-%d'),

# %%
questions
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 299,
#  'total': 0,
#  'items': [{'tags': ['python', 'pip', 'debian', 'failed-installation'],
#    'owner': {'account_id': 23480036,
#     'reputation': 8915,
#     'user_id': 17532318,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/d37672946ecec10b2814be93daa910ef?s=256&d=identicon&r=PG',
#     'display_name': 'Apoliticalboy',
#     'link': 'https://stackoverflow.com/users/17532318/apoliticalboy'},
#    'is_answered': True,
#    'view_count': 1665883,
#    'protected_date': 1721306261,
#    'answer_count': 41,
#    'score': 877,
#    'last_activity_date': 1743079178,
#    'creation_date': 1677700339,
#    'last_edit_date': 1736974120,
#    'question_id': 75608323,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75608323/how-do-i-solve-error-externally-managed-environment-every-time-i-use-pip-3',
#    'title': 'How do I solve &quot;error: externally-managed-environment&quot; every time I use pip 3?'},
#   {'tags': ['python',
#     'pandas',
#     'dataframe',
#     'concatenation',
#     'attributeerror'],
#    'owner': {'account_id': 18651684,
#     'reputation': 3371,
#     'user_id': 13595011,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14Gja1Bf3zfNP7LY4HSFgp6beG2pul2AVcXIsoLC52g=k-s256',
#     'display_name': 'Maksimjeet Chowdhary',
#     'link': 'https://stackoverflow.com/users/13595011/maksimjeet-chowdhary'},
#    'is_answered': True,
#    'view_count': 710009,
#    'protected_date': 1695993982,
#    'answer_count': 3,
#    'score': 317,
#    'last_activity_date': 1737571523,
#    'creation_date': 1680851159,
#    'last_edit_date': 1737571523,
#    'question_id': 75956209,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75956209/error-dataframe-object-has-no-attribute-append',
#    'title': 'Error &quot;&#39;DataFrame&#39; object has no attribute &#39;append&#39;&quot;'},
#   {'tags': ['python', 'macos', 'terminal', 'atom-editor', 'macos-monterey'],
#    'owner': {'account_id': 24663681,
#     'reputation': 4634,
#     'user_id': 18559642,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/13cdab4eb9d9fb5b1c7dece549f96046?s=256&d=identicon&r=PG',
#     'display_name': 'Kirill Ignatyev',
#     'link': 'https://stackoverflow.com/users/18559642/kirill-ignatyev'},
#    'is_answered': True,
#    'view_count': 661708,
#    'protected_date': 1673118234,
#    'accepted_answer_id': 71621142,
#    'answer_count': 21,
#    'score': 266,
#    'last_activity_date': 1738689626,
#    'creation_date': 1648058522,
#    'last_edit_date': 1656277606,
#    'question_id': 71591971,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71591971/how-can-i-fix-the-zsh-command-not-found-python-error-macos-monterey-12-3',
#    'title': 'How can I fix the &quot;zsh: command not found: python&quot; error? (macOS Monterey 12.3, Python&amp;nbsp;3.10, Atom IDE, and atom-python-run 0.9.7)'},
#   {'tags': ['python', 'tensorflow', 'ray'],
#    'owner': {'account_id': 22989345,
#     'reputation': 2281,
#     'user_id': 17115086,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/16c137f7793988efb97ab410f7aec4f6?s=256&d=identicon&r=PG',
#     'display_name': 'hasu33',
#     'link': 'https://stackoverflow.com/users/17115086/hasu33'},
#    'is_answered': True,
#    'view_count': 375570,
#    'protected_date': 1689017298,
#    'answer_count': 17,
#    'score': 223,
#    'last_activity_date': 1704509020,
#    'creation_date': 1653965255,
#    'last_edit_date': 1656248470,
#    'question_id': 72441758,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72441758/typeerror-descriptors-cannot-not-be-created-directly',
#    'title': 'TypeError: Descriptors cannot not be created directly'},
#   {'tags': ['python', 'python-3.x', 'numpy', 'pip'],
#    'owner': {'account_id': 6714573,
#     'reputation': 2469,
#     'user_id': 6323020,
#     'user_type': 'registered',
#     'accept_rate': 50,
#     'profile_image': 'https://www.gravatar.com/avatar/ca1065f7cc55d81ea1ea374b14113ac4?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'sreeraj t',
#     'link': 'https://stackoverflow.com/users/6323020/sreeraj-t'},
#    'is_answered': True,
#    'view_count': 349754,
#    'protected_date': 1712051464,
#    'accepted_answer_id': 77364602,
#    'answer_count': 8,
#    'score': 218,
#    'last_activity_date': 1725410425,
#    'creation_date': 1698301344,
#    'last_edit_date': 1725410425,
#    'question_id': 77364550,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/77364550/attributeerror-module-pkgutil-has-no-attribute-impimporter-did-you-mean',
#    'title': 'AttributeError: module &#39;pkgutil&#39; has no attribute &#39;ImpImporter&#39;. Did you mean: &#39;zipimporter&#39;?'},
#   {'tags': ['python', 'flask', 'pytest', 'werkzeug'],
#    'owner': {'account_id': 20745029,
#     'reputation': 2683,
#     'user_id': 15233792,
#     'user_type': 'registered',
#     'profile_image': 'https://i.sstatic.net/2ol6b.jpg?s=256',
#     'display_name': 'stevezkw',
#     'link': 'https://stackoverflow.com/users/15233792/stevezkw'},
#    'is_answered': True,
#    'view_count': 202658,
#    'protected_date': 1698079880,
#    'accepted_answer_id': 77214086,
#    'answer_count': 6,
#    'score': 201,
#    'last_activity_date': 1708084399,
#    'creation_date': 1696215720,
#    'last_edit_date': 1700174126,
#    'question_id': 77213053,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/77213053/why-did-flask-start-failing-with-importerror-cannot-import-name-url-quote-fr',
#    'title': 'Why did Flask start failing with &quot;ImportError: cannot import name &#39;url_quote&#39; from &#39;werkzeug.urls&#39;&quot;?'},
#   {'tags': ['python', 'machine-learning', 'package', 'conda', 'python-poetry'],
#    'owner': {'account_id': 1449869,
#     'reputation': 3212,
#     'user_id': 1367124,
#     'user_type': 'registered',
#     'accept_rate': 68,
#     'profile_image': 'https://i.sstatic.net/azGrD.jpg?s=256',
#     'display_name': 'Seub',
#     'link': 'https://stackoverflow.com/users/1367124/seub'},
#    'is_answered': True,
#    'view_count': 107284,
#    'accepted_answer_id': 71110028,
#    'answer_count': 6,
#    'score': 200,
#    'last_activity_date': 1736208444,
#    'creation_date': 1643123383,
#    'last_edit_date': 1724784791,
#    'question_id': 70851048,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/70851048/does-it-make-sense-to-use-conda-poetry',
#    'title': 'Does it make sense to use Conda + Poetry?'},
#   {'tags': ['python', 'google-analytics-api'],
#    'owner': {'account_id': 6468208,
#     'reputation': 7127,
#     'user_id': 5009293,
#     'user_type': 'registered',
#     'accept_rate': 76,
#     'profile_image': 'https://graph.facebook.com/995762863775266/picture?type=large',
#     'display_name': 'Doug Coats',
#     'link': 'https://stackoverflow.com/users/5009293/doug-coats'},
#    'is_answered': True,
#    'view_count': 348969,
#    'accepted_answer_id': 73932621,
#    'answer_count': 21,
#    'score': 190,
#    'last_activity_date': 1712734945,
#    'creation_date': 1663949925,
#    'last_edit_date': 1704753149,
#    'question_id': 73830524,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/73830524/attributeerror-module-lib-has-no-attribute-x509-v-flag-cb-issuer-check',
#    'title': 'AttributeError: module &#39;lib&#39; has no attribute &#39;X509_V_FLAG_CB_ISSUER_CHECK&#39;'},
#   {'tags': ['python', 'python-black'],
#    'owner': {'account_id': 13900281,
#     'reputation': 12824,
#     'user_id': 10036039,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/8790cbc891c02fffb597317b43a063fa?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'zerocewl',
#     'link': 'https://stackoverflow.com/users/10036039/zerocewl'},
#    'is_answered': True,
#    'view_count': 91785,
#    'accepted_answer_id': 71674345,
#    'answer_count': 6,
#    'score': 184,
#    'last_activity_date': 1701665110,
#    'creation_date': 1648626375,
#    'last_edit_date': 1651785651,
#    'question_id': 71673404,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71673404/importerror-cannot-import-name-unicodefun-from-click',
#    'title': 'ImportError: cannot import name &#39;_unicodefun&#39; from &#39;click&#39;'},
#   {'tags': ['python', 'pandas', 'dataframe', 'data-wrangling', 'data-munging'],
#    'owner': {'account_id': 29727,
#     'reputation': 5111,
#     'user_id': 80544,
#     'user_type': 'registered',
#     'accept_rate': 79,
#     'profile_image': 'https://i.sstatic.net/HtN07.jpg?s=256',
#     'display_name': 'Glenn',
#     'link': 'https://stackoverflow.com/users/80544/glenn'},
#    'is_answered': True,
#    'view_count': 252954,
#    'accepted_answer_id': 70837545,
#    'answer_count': 9,
#    'score': 182,
#    'last_activity_date': 1732298512,
#    'creation_date': 1643042804,
#    'last_edit_date': 1732298512,
#    'question_id': 70837397,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/70837397/good-alternative-to-pandas-append-method-now-that-it-has-been-deprecated',
#    'title': 'Good alternative to Pandas .append() method, now that it has been deprecated?'},
#   {'tags': ['python', 'openai-api', 'urllib3'],
#    'owner': {'account_id': 11229285,
#     'reputation': 1853,
#     'user_id': 8237910,
#     'user_type': 'registered',
#     'profile_image': 'https://lh5.googleusercontent.com/-OajeBMxDGMo/AAAAAAAAAAI/AAAAAAAAAmQ/8vm8L0FQK1c/photo.jpg?sz=256',
#     'display_name': 'maimai',
#     'link': 'https://stackoverflow.com/users/8237910/maimai'},
#    'is_answered': True,
#    'view_count': 411401,
#    'accepted_answer_id': 76187415,
#    'answer_count': 19,
#    'score': 174,
#    'last_activity_date': 1733400333,
#    'creation_date': 1683349902,
#    'last_edit_date': 1691972425,
#    'question_id': 76187256,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/76187256/importerror-urllib3-v2-0-only-supports-openssl-1-1-1-currently-the-ssl-modu',
#    'title': 'ImportError: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the &#39;ssl&#39; module is compiled with LibreSSL 2.8.3'},
#   {'tags': ['python', 'prompt', 'openai-api', 'completion', 'chatgpt-api'],
#    'owner': {'account_id': 3235065,
#     'reputation': 2694,
#     'user_id': 3018860,
#     'user_type': 'registered',
#     'accept_rate': 89,
#     'profile_image': 'https://www.gravatar.com/avatar/edec84abcde58e8f5d45a7e5522ff1e1?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'Unix',
#     'link': 'https://stackoverflow.com/users/3018860/unix'},
#    'is_answered': True,
#    'view_count': 429804,
#    'closed_date': 1685124780,
#    'accepted_answer_id': 75898717,
#    'answer_count': 5,
#    'score': 174,
#    'last_activity_date': 1736482616,
#    'creation_date': 1680263884,
#    'last_edit_date': 1704294387,
#    'question_id': 75898276,
#    'link': 'https://stackoverflow.com/questions/75898276/openai-api-error-429-you-exceeded-your-current-quota-please-check-your-plan-a',
#    'closed_reason': 'Not suitable for this site',
#    'title': 'OpenAI API error 429: &quot;You exceeded your current quota, please check your plan and billing details&quot;'},
#   {'tags': ['python', 'linux'],
#    'owner': {'account_id': 27907651,
#     'reputation': 1775,
#     'user_id': 21310501,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AGNmyxb3a8PSNvhapdvFSFi0i8vX_XG9vbYoqiUUjBzk=k-s256',
#     'display_name': 'iReXes ',
#     'link': 'https://stackoverflow.com/users/21310501/irexes'},
#    'is_answered': True,
#    'view_count': 534216,
#    'closed_date': 1719028471,
#    'answer_count': 12,
#    'score': 165,
#    'last_activity_date': 1736973671,
#    'creation_date': 1677664429,
#    'last_edit_date': 1694076936,
#    'question_id': 75602063,
#    'link': 'https://stackoverflow.com/questions/75602063/pip-install-r-requirements-txt-is-failing-this-environment-is-externally-mana',
#    'closed_reason': 'Duplicate',
#    'title': 'pip install -r requirements.txt is failing: &quot;This environment is externally managed&quot;'},
#   {'tags': ['python', 'numpy', 'matlab', 'spacy'],
#    'owner': {'account_id': 12941972,
#     'reputation': 3068,
#     'user_id': 9357484,
#     'user_type': 'registered',
#     'accept_rate': 50,
#     'profile_image': 'https://i.sstatic.net/x0wQp.png?s=256',
#     'display_name': 'Encipher',
#     'link': 'https://stackoverflow.com/users/9357484/encipher'},
#    'is_answered': True,
#    'view_count': 190708,
#    'accepted_answer_id': 78641304,
#    'answer_count': 8,
#    'score': 156,
#    'last_activity_date': 1742689359,
#    'creation_date': 1718650377,
#    'last_edit_date': 1719996645,
#    'question_id': 78634235,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/78634235/numpy-dtype-size-changed-may-indicate-binary-incompatibility-expected-96-from',
#    'title': 'numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject'},
#   {'tags': ['python', 'python-typing'],
#    'owner': {'account_id': 1881254,
#     'reputation': 2218,
#     'user_id': 1701415,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/cb5160e829bd4a3a0863e8bd6cff9aea?s=256&d=identicon&r=PG',
#     'display_name': 'Jesse',
#     'link': 'https://stackoverflow.com/users/1701415/jesse'},
#    'is_answered': True,
#    'view_count': 115143,
#    'protected_date': 1724828109,
#    'accepted_answer_id': 76399911,
#    'answer_count': 6,
#    'score': 146,
#    'last_activity_date': 1733304353,
#    'creation_date': 1650158620,
#    'last_edit_date': 1724884778,
#    'question_id': 71898644,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71898644/how-to-use-python-typing-annotated',
#    'title': 'How to use python typing.Annotated'},
#   {'tags': ['python',
#     'docker',
#     'docker-compose',
#     'dependencies',
#     'importerror'],
#    'owner': {'account_id': 3369545,
#     'reputation': 3593,
#     'user_id': 2829150,
#     'user_type': 'registered',
#     'accept_rate': 51,
#     'profile_image': 'https://www.gravatar.com/avatar/1e9c788890b3d2a8e468ed2773864b2c?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'Arie',
#     'link': 'https://stackoverflow.com/users/2829150/arie'},
#    'is_answered': True,
#    'view_count': 207110,
#    'protected_date': 1691442712,
#    'answer_count': 15,
#    'score': 143,
#    'last_activity_date': 1699634829,
#    'creation_date': 1652208276,
#    'last_edit_date': 1667754370,
#    'question_id': 72191560,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72191560/importerror-cannot-import-name-soft-unicode-from-markupsafe',
#    'title': 'ImportError: cannot import name &#39;soft_unicode&#39; from &#39;markupsafe&#39;'},
#   {'tags': ['python', 'linux', 'openssl', 'python-poetry'],
#    'owner': {'account_id': 7489950,
#     'reputation': 5546,
#     'user_id': 5692012,
#     'user_type': 'registered',
#     'accept_rate': 50,
#     'profile_image': 'https://i.sstatic.net/a3FwR.gif?s=256',
#     'display_name': 'RobinFrcd',
#     'link': 'https://stackoverflow.com/users/5692012/robinfrcd'},
#    'is_answered': True,
#    'view_count': 324339,
#    'accepted_answer_id': 72633324,
#    'answer_count': 16,
#    'score': 141,
#    'last_activity_date': 1737307651,
#    'creation_date': 1651782719,
#    'last_edit_date': 1675089528,
#    'question_id': 72133316,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72133316/libssl-so-1-1-cannot-open-shared-object-file-no-such-file-or-directory',
#    'title': 'libssl.so.1.1: cannot open shared object file: No such file or directory'},
#   {'tags': ['python', 'compiler-errors', 'jinja2', 'pydash'],
#    'owner': {'account_id': 24471670,
#     'reputation': 1462,
#     'user_id': 18391313,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/6daa890351c0aa7a81f5818633ad0893?s=256&d=identicon&r=PG',
#     'display_name': 'Bheshaj',
#     'link': 'https://stackoverflow.com/users/18391313/bheshaj'},
#    'is_answered': True,
#    'view_count': 209994,
#    'accepted_answer_id': 71735103,
#    'answer_count': 9,
#    'score': 136,
#    'last_activity_date': 1723958976,
#    'creation_date': 1648907775,
#    'last_edit_date': 1723958976,
#    'question_id': 71718167,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71718167/importerror-cannot-import-name-escape-from-jinja2',
#    'title': 'ImportError: cannot import name &#39;escape&#39; from &#39;jinja2&#39;'},
#   {'tags': ['python',
#     'selenium',
#     'google-chrome',
#     'selenium-webdriver',
#     'selenium-chromedriver'],
#    'owner': {'account_id': 19488994,
#     'reputation': 1453,
#     'user_id': 14257612,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/c49440f3d6f3831211bcb56d9614a61e?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'Alesss',
#     'link': 'https://stackoverflow.com/users/14257612/alesss'},
#    'is_answered': True,
#    'view_count': 318405,
#    'accepted_answer_id': 72773269,
#    'answer_count': 6,
#    'score': 135,
#    'last_activity_date': 1725862890,
#    'creation_date': 1656337711,
#    'last_edit_date': 1661689426,
#    'question_id': 72773206,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72773206/selenium-python-attributeerror-webdriver-object-has-no-attribute-find-el',
#    'title': 'Selenium - Python - AttributeError: &#39;WebDriver&#39; object has no attribute &#39;find_element_by_name&#39;'},
#   {'tags': ['python', 'python-imaging-library'],
#    'owner': {'account_id': 26367272,
#     'reputation': 1313,
#     'user_id': 20022511,
#     'user_type': 'registered',
#     'profile_image': 'https://i.sstatic.net/zvtp5.png?s=256',
#     'display_name': 'MT_276',
#     'link': 'https://stackoverflow.com/users/20022511/mt-276'},
#    'is_answered': True,
#    'view_count': 216054,
#    'accepted_answer_id': 76744441,
#    'answer_count': 9,
#    'score': 120,
#    'last_activity_date': 1724047889,
#    'creation_date': 1688507881,
#    'last_edit_date': 1704562499,
#    'question_id': 76616042,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/76616042/attributeerror-module-pil-image-has-no-attribute-antialias',
#    'title': 'AttributeError: module &#39;PIL.Image&#39; has no attribute &#39;ANTIALIAS&#39;'},
#   {'tags': ['python', 'pip'],
#    'owner': {'account_id': 15449541,
#     'reputation': 1239,
#     'user_id': 17660775,
#     'user_type': 'registered',
#     'profile_image': 'https://graph.facebook.com/2328891030722501/picture?type=large',
#     'display_name': 'Abdeldjalil Sekkal',
#     'link': 'https://stackoverflow.com/users/17660775/abdeldjalil-sekkal'},
#    'is_answered': True,
#    'view_count': 227092,
#    'protected_date': 1676571122,
#    'answer_count': 11,
#    'score': 107,
#    'last_activity_date': 1714268093,
#    'creation_date': 1653937478,
#    'last_edit_date': 1702941130,
#    'question_id': 72439001,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72439001/there-was-an-error-checking-the-latest-version-of-pip',
#    'title': 'There was an error checking the latest version of pip'},
#   {'tags': ['python', 'windows', 'visual-studio-2022'],
#    'owner': {'account_id': 2813476,
#     'reputation': 1843,
#     'user_id': 2419205,
#     'user_type': 'registered',
#     'accept_rate': 52,
#     'profile_image': 'https://www.gravatar.com/avatar/5a4b5ff5c0d06ba079e8d974dd8309b4?s=256&d=identicon&r=PG',
#     'display_name': 'Starfleet Security',
#     'link': 'https://stackoverflow.com/users/2419205/starfleet-security'},
#    'is_answered': True,
#    'view_count': 8035,
#    'answer_count': 9,
#    'score': 107,
#    'last_activity_date': 1668277374,
#    'creation_date': 1645204638,
#    'last_edit_date': 1648802107,
#    'question_id': 71177450,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71177450/unable-to-restore-visual-studio-2022-window-ide-itself-after-minimizing',
#    'title': 'Unable to restore Visual Studio 2022 window (IDE itself) after minimizing'},
#   {'tags': ['python',
#     'string',
#     'reference',
#     'immutability',
#     'string-concatenation'],
#    'owner': {'account_id': 6666507,
#     'reputation': 1255,
#     'user_id': 5144013,
#     'user_type': 'registered',
#     'accept_rate': 44,
#     'profile_image': 'https://lh3.googleusercontent.com/-gaua46VyxKQ/AAAAAAAAAAI/AAAAAAAAHxg/M-29RPq_C6E/photo.jpg?sz=256',
#     'display_name': 'Master_Roshy',
#     'link': 'https://stackoverflow.com/users/5144013/master-roshy'},
#    'is_answered': True,
#    'view_count': 7389,
#    'protected_date': 1657262192,
#    'answer_count': 4,
#    'score': 103,
#    'last_activity_date': 1657261330,
#    'creation_date': 1654830500,
#    'last_edit_date': 1654982358,
#    'question_id': 72568719,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72568719/if-python-strings-are-immutable-why-does-it-keep-the-same-id-if-i-use-to-app',
#    'title': 'If Python strings are immutable, why does it keep the same id if I use += to append to it?'},
#   {'tags': ['python', 'ubuntu', 'pip', 'windows-subsystem-for-linux'],
#    'owner': {'account_id': 7752222,
#     'reputation': 1225,
#     'user_id': 6799513,
#     'user_type': 'registered',
#     'profile_image': 'https://i.sstatic.net/Bha40.jpg?s=256',
#     'display_name': 'patrick',
#     'link': 'https://stackoverflow.com/users/6799513/patrick'},
#    'is_answered': True,
#    'view_count': 106980,
#    'accepted_answer_id': 75053968,
#    'answer_count': 4,
#    'score': 102,
#    'last_activity_date': 1702742218,
#    'creation_date': 1672657056,
#    'last_edit_date': 1672657567,
#    'question_id': 74981558,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/74981558/error-updating-python3-pip-attributeerror-module-lib-has-no-attribute-openss',
#    'title': 'Error Updating Python3 pip AttributeError: module &#39;lib&#39; has no attribute &#39;OpenSSL_add_all_algorithms&#39;'},
#   {'tags': ['python', 'cpython', 'python-internals'],
#    'owner': {'account_id': 17476274,
#     'reputation': 27654,
#     'user_id': 12671057,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/90d2e6942c69df199a95d06e0c8e9a10?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'Kelly Bundy',
#     'link': 'https://stackoverflow.com/users/12671057/kelly-bundy'},
#    'is_answered': True,
#    'view_count': 8719,
#    'closed_date': 1643494282,
#    'accepted_answer_id': 70882093,
#    'answer_count': 3,
#    'score': 101,
#    'last_activity_date': 1644084297,
#    'creation_date': 1643300597,
#    'last_edit_date': 1644083484,
#    'question_id': 70882092,
#    'link': 'https://stackoverflow.com/questions/70882092/can-we-make-1-2-true',
#    'closed_reason': 'Duplicate',
#    'title': 'Can we make 1 == 2 true?'},
#   {'tags': ['python',
#     'asynchronous',
#     'concurrency',
#     'python-asyncio',
#     'fastapi'],
#    'owner': {'account_id': 1237641,
#     'reputation': 2852,
#     'user_id': 1200914,
#     'user_type': 'registered',
#     'accept_rate': 89,
#     'profile_image': 'https://www.gravatar.com/avatar/d3c21d029de13a98c973b98f28ad6867?s=256&d=identicon&r=PG',
#     'display_name': 'Learning from masters',
#     'link': 'https://stackoverflow.com/users/1200914/learning-from-masters'},
#    'is_answered': True,
#    'view_count': 82795,
#    'protected_date': 1685986311,
#    'accepted_answer_id': 71517830,
#    'answer_count': 2,
#    'score': 99,
#    'last_activity_date': 1740292815,
#    'creation_date': 1647535766,
#    'last_edit_date': 1737876433,
#    'question_id': 71516140,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71516140/fastapi-runs-api-calls-in-serial-instead-of-parallel-fashion',
#    'title': 'FastAPI runs API calls in serial instead of parallel fashion'},
#   {'tags': ['python', 'python-typing'],
#    'owner': {'account_id': 24765622,
#     'reputation': 1398,
#     'user_id': 18649495,
#     'user_type': 'registered',
#     'profile_image': 'https://i.sstatic.net/tG5JN.jpg?s=256',
#     'display_name': 'Fed_Dragon',
#     'link': 'https://stackoverflow.com/users/18649495/fed-dragon'},
#    'is_answered': True,
#    'view_count': 32161,
#    'accepted_answer_id': 72158086,
#    'answer_count': 3,
#    'score': 96,
#    'last_activity_date': 1721427446,
#    'creation_date': 1651970217,
#    'last_edit_date': 1721427446,
#    'question_id': 72157296,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72157296/what-is-the-difference-between-type-hinting-a-variable-as-an-iterable-versus-a-s',
#    'title': 'What is the difference between type-hinting a variable as an Iterable versus a Sequence?'},
#   {'tags': ['python', 'ffmpeg', 'discord', 'youtube-dl'],
#    'owner': {'account_id': 27587346,
#     'reputation': 967,
#     'user_id': 21055247,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/AEdFTp68sX4uwH8oI00wq1qnsHwmhUC3m9kFQUea4JSE=k-s256',
#     'display_name': 'nikita goncharov',
#     'link': 'https://stackoverflow.com/users/21055247/nikita-goncharov'},
#    'is_answered': True,
#    'view_count': 126941,
#    'accepted_answer_id': 75504772,
#    'answer_count': 10,
#    'score': 94,
#    'last_activity_date': 1721680970,
#    'creation_date': 1676747963,
#    'last_edit_date': 1700757654,
#    'question_id': 75495800,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75495800/error-unable-to-extract-uploader-id-youtube-discord-py',
#    'title': 'Error: Unable to extract uploader id - Youtube, Discord.py'},
#   {'tags': ['python', 'pip', 'setuptools', 'pyproject.toml'],
#    'owner': {'account_id': 2017134,
#     'reputation': 26799,
#     'user_id': 1804173,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/53f721a451a1c68caf8316cefcde3083?s=256&d=identicon&r=PG',
#     'display_name': 'bluenote10',
#     'link': 'https://stackoverflow.com/users/1804173/bluenote10'},
#    'is_answered': True,
#    'view_count': 55021,
#    'accepted_answer_id': 73600610,
#    'answer_count': 3,
#    'score': 92,
#    'last_activity_date': 1732037098,
#    'creation_date': 1662300788,
#    'last_edit_date': 1667985506,
#    'question_id': 73600082,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/73600082/how-to-reference-a-requirements-txt-in-the-pyproject-toml-of-a-setuptools-projec',
#    'title': 'How to reference a requirements.txt in the pyproject.toml of a setuptools project?'},
#   {'tags': ['python', 'python-poetry'],
#    'owner': {'account_id': 442058,
#     'reputation': 541,
#     'user_id': 832490,
#     'user_type': 'registered',
#     'accept_rate': 100,
#     'profile_image': 'https://www.gravatar.com/avatar/38de998f10120ac8f0dab7f193bedf2b?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'Rodrigo',
#     'link': 'https://stackoverflow.com/users/832490/rodrigo'},
#    'is_answered': True,
#    'view_count': 69774,
#    'accepted_answer_id': 72547402,
#    'answer_count': 3,
#    'score': 90,
#    'last_activity_date': 1730975366,
#    'creation_date': 1652898582,
#    'last_edit_date': 1652904288,
#    'question_id': 72294299,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72294299/multiple-top-level-packages-discovered-in-a-flat-layout',
#    'title': 'Multiple top-level packages discovered in a flat-layout'},
#   {'tags': ['python', 'c++', 'python-3.x', 'rounding', 'integer-division'],
#    'owner': {'account_id': 7923772,
#     'reputation': 7536,
#     'user_id': 5983841,
#     'user_type': 'registered',
#     'accept_rate': 62,
#     'profile_image': 'https://i.sstatic.net/GHJxG.jpg?s=256',
#     'display_name': 'Rick',
#     'link': 'https://stackoverflow.com/users/5983841/rick'},
#    'is_answered': True,
#    'view_count': 8963,
#    'accepted_answer_id': 70735005,
#    'answer_count': 8,
#    'score': 88,
#    'last_activity_date': 1660790087,
#    'creation_date': 1642342052,
#    'last_edit_date': 1643506145,
#    'question_id': 70730831,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/70730831/whats-the-mathematical-reason-behind-python-choosing-to-round-integer-division',
#    'title': 'What&#39;s the mathematical reason behind Python choosing to round integer division toward negative infinity?'},
#   {'tags': ['python', 'python-3.x', 'pip'],
#    'owner': {'account_id': 23650540,
#     'reputation': 935,
#     'user_id': 17679479,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14Gir3m-DTE1Yx2GwtNYJ0w02mRyRj-8yB5ZPmIx5=k-s256',
#     'display_name': 'BRICK MANE',
#     'link': 'https://stackoverflow.com/users/17679479/brick-mane'},
#    'is_answered': True,
#    'view_count': 209573,
#    'answer_count': 20,
#    'score': 87,
#    'last_activity_date': 1740671428,
#    'creation_date': 1643729700,
#    'last_edit_date': 1658994516,
#    'question_id': 70943244,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/70943244/attributeerror-module-collections-has-no-attribute-mutablemapping',
#    'title': 'AttributeError: module &#39;collections&#39; has no attribute &#39;MutableMapping&#39;'},
#   {'tags': ['python', 'openai-api', 'chatgpt-api', 'gpt-3', 'gpt-4'],
#    'owner': {'account_id': 5699987,
#     'reputation': 1514,
#     'user_id': 4505301,
#     'user_type': 'registered',
#     'profile_image': 'https://i.sstatic.net/Zko8X.jpg?s=256',
#     'display_name': 'meliksahturker',
#     'link': 'https://stackoverflow.com/users/4505301/meliksahturker'},
#    'is_answered': True,
#    'view_count': 99933,
#    'accepted_answer_id': 75804651,
#    'answer_count': 4,
#    'score': 87,
#    'last_activity_date': 1716198456,
#    'creation_date': 1679420110,
#    'last_edit_date': 1712708782,
#    'question_id': 75804599,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75804599/openai-api-how-do-i-count-tokens-before-i-send-an-api-request',
#    'title': 'OpenAI API: How do I count tokens before(!) I send an API request?'},
#   {'tags': ['python', 'swift', 'xcode'],
#    'owner': {'account_id': 30677402,
#     'reputation': 915,
#     'user_id': 23519070,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a/ACg8ocLZxBb5di_42wV3YgLeHeZclOX0bWtz1lY9cKm5JB1Po_c=k-s256',
#     'display_name': 'James Menkal',
#     'link': 'https://stackoverflow.com/users/23519070/james-menkal'},
#    'is_answered': True,
#    'view_count': 59771,
#    'protected_date': 1718421403,
#    'accepted_answer_id': 78204720,
#    'answer_count': 4,
#    'score': 86,
#    'last_activity_date': 1719986022,
#    'creation_date': 1709927540,
#    'last_edit_date': 1709931544,
#    'question_id': 78129981,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/78129981/logging-error-failed-to-initialize-logging-system-log-messages-may-be-missing',
#    'title': 'Logging Error: Failed to initialize logging system. Log messages may be missing.?'},
#   {'tags': ['python', 'python-poetry'],
#    'owner': {'account_id': 5622044,
#     'reputation': 10082,
#     'user_id': 4451521,
#     'user_type': 'registered',
#     'accept_rate': 34,
#     'profile_image': 'https://www.gravatar.com/avatar/4b19b54142d820aad565ca95f920c11c?s=256&d=identicon&r=PG',
#     'display_name': 'KansaiRobot',
#     'link': 'https://stackoverflow.com/users/4451521/kansairobot'},
#    'is_answered': True,
#    'view_count': 68264,
#    'answer_count': 5,
#    'score': 84,
#    'last_activity_date': 1727101741,
#    'creation_date': 1675940902,
#    'question_id': 75397736,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75397736/poetry-install-on-an-existing-project-error-does-not-contain-any-element',
#    'title': 'Poetry install on an existing project Error &quot;does not contain any element&quot;'},
#   {'tags': ['python', 'ssl', 'openssl', 'runtime-error'],
#    'owner': {'account_id': 17018517,
#     'reputation': 961,
#     'user_id': 12311729,
#     'user_type': 'registered',
#     'profile_image': 'https://graph.facebook.com/2152598004840080/picture?type=large',
#     'display_name': 'Gianmarco Broilo',
#     'link': 'https://stackoverflow.com/users/12311729/gianmarco-broilo'},
#    'is_answered': True,
#    'view_count': 213191,
#    'protected_date': 1720117247,
#    'accepted_answer_id': 72374542,
#    'answer_count': 11,
#    'score': 83,
#    'last_activity_date': 1719931665,
#    'creation_date': 1648128152,
#    'last_edit_date': 1700615763,
#    'question_id': 71603314,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71603314/ssl-error-unsafe-legacy-renegotiation-disabled',
#    'title': 'SSL error unsafe legacy renegotiation disabled'},
#   {'tags': ['python', 'tensorflow', 'conda', 'apple-m1'],
#    'owner': {'account_id': 114708,
#     'reputation': 12555,
#     'user_id': 301513,
#     'user_type': 'registered',
#     'accept_rate': 47,
#     'profile_image': 'https://i.sstatic.net/oWFRY.png?s=256',
#     'display_name': 'Qiulang',
#     'link': 'https://stackoverflow.com/users/301513/qiulang'},
#    'is_answered': True,
#    'view_count': 101840,
#    'protected_date': 1694544271,
#    'answer_count': 15,
#    'score': 83,
#    'last_activity_date': 1732187271,
#    'creation_date': 1657708328,
#    'last_edit_date': 1695005358,
#    'question_id': 72964800,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72964800/what-is-the-proper-way-to-install-tensorflow-on-apple-m1-in-2022',
#    'title': 'What is the proper way to install TensorFlow on Apple M1 in 2022'},
#   {'tags': ['python', 'pre-commit', 'pre-commit.com', 'isort'],
#    'owner': {'account_id': 8247924,
#     'reputation': 6384,
#     'user_id': 6203472,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/6854a8b5ed6ad561c0ab878c7558fb26?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'bagerard',
#     'link': 'https://stackoverflow.com/users/6203472/bagerard'},
#    'is_answered': True,
#    'view_count': 18723,
#    'accepted_answer_id': 75269701,
#    'answer_count': 5,
#    'score': 81,
#    'last_activity_date': 1678725721,
#    'creation_date': 1674928449,
#    'last_edit_date': 1675093819,
#    'question_id': 75269700,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/75269700/pre-commit-fails-to-install-isort-5-11-4-with-error-runtimeerror-the-poetry-co',
#    'title': 'pre-commit fails to install isort 5.11.4 with error &quot;RuntimeError: The Poetry configuration is invalid&quot;'},
#   {'tags': ['python', 'json', 'dictionary', 'python-dataclasses'],
#    'owner': {'account_id': 14841576,
#     'reputation': 1248,
#     'user_id': 10718164,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/acc4f37c0049f3694dd50ae7b9a463a5?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'Unknown',
#     'link': 'https://stackoverflow.com/users/10718164/unknown'},
#    'is_answered': True,
#    'view_count': 138107,
#    'accepted_answer_id': 72605423,
#    'answer_count': 4,
#    'score': 81,
#    'last_activity_date': 1712378529,
#    'creation_date': 1655132088,
#    'last_edit_date': 1655132451,
#    'question_id': 72604922,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72604922/how-to-convert-python-dataclass-to-dictionary-of-string-literal',
#    'title': 'How to convert Python dataclass to dictionary of string literal?'},
#   {'tags': ['python',
#     'python-packaging',
#     'requirements.txt',
#     'pyproject.toml'],
#    'owner': {'account_id': 3439063,
#     'reputation': 16880,
#     'user_id': 2881414,
#     'user_type': 'registered',
#     'accept_rate': 56,
#     'profile_image': 'https://i.sstatic.net/HRfVv.jpg?s=256',
#     'display_name': 'Bastian Venthur',
#     'link': 'https://stackoverflow.com/users/2881414/bastian-venthur'},
#    'is_answered': True,
#    'view_count': 37781,
#    'accepted_answer_id': 74625055,
#    'answer_count': 5,
#    'score': 79,
#    'last_activity_date': 1730279641,
#    'creation_date': 1668946731,
#    'last_edit_date': 1687651968,
#    'question_id': 74508024,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/74508024/is-requirements-txt-still-needed-when-using-pyproject-toml',
#    'title': 'Is requirements.txt still needed when using pyproject.toml?'},
#   {'tags': ['python', 'performance', 'comparison'],
#    'owner': {'account_id': 393493,
#     'reputation': 5131,
#     'user_id': 755371,
#     'user_type': 'registered',
#     'accept_rate': 44,
#     'profile_image': 'https://i.sstatic.net/Cmp2K.png?s=256',
#     'display_name': 'Eric',
#     'link': 'https://stackoverflow.com/users/755371/eric'},
#    'is_answered': True,
#    'view_count': 8494,
#    'closed_date': 1648640765,
#    'accepted_answer_id': 71644988,
#    'answer_count': 2,
#    'score': 77,
#    'last_activity_date': 1648641525,
#    'creation_date': 1648455910,
#    'last_edit_date': 1648563343,
#    'question_id': 71644405,
#    'link': 'https://stackoverflow.com/questions/71644405/why-is-it-faster-to-compare-strings-that-match-than-strings-that-do-not',
#    'closed_reason': 'Duplicate',
#    'title': 'Why is it faster to compare strings that match than strings that do not?'},
#   {'tags': ['python', 'django', 'digital-ocean'],
#    'owner': {'account_id': 8967886,
#     'reputation': 4020,
#     'user_id': 6687699,
#     'user_type': 'registered',
#     'accept_rate': 58,
#     'profile_image': 'https://i.sstatic.net/4Snxy.jpg?s=256',
#     'display_name': 'Lutaaya Huzaifah Idris',
#     'link': 'https://stackoverflow.com/users/6687699/lutaaya-huzaifah-idris'},
#    'is_answered': True,
#    'view_count': 56104,
#    'accepted_answer_id': 73932581,
#    'answer_count': 6,
#    'score': 76,
#    'last_activity_date': 1704807596,
#    'creation_date': 1664747002,
#    'question_id': 73929564,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/73929564/entrypoints-object-has-no-attribute-get-digital-ocean',
#    'title': '&#39;EntryPoints&#39; object has no attribute &#39;get&#39; - Digital ocean'},
#   {'tags': ['python', 'numpy'],
#    'owner': {'account_id': 12810242,
#     'reputation': 1004,
#     'user_id': 9481479,
#     'user_type': 'registered',
#     'profile_image': 'https://graph.facebook.com/1769985833305230/picture?type=large',
#     'display_name': 'Nawin K Sharma',
#     'link': 'https://stackoverflow.com/users/9481479/nawin-k-sharma'},
#    'is_answered': True,
#    'view_count': 174563,
#    'accepted_answer_id': 74861894,
#    'answer_count': 9,
#    'score': 75,
#    'last_activity_date': 1731458268,
#    'creation_date': 1671396136,
#    'last_edit_date': 1677183023,
#    'question_id': 74844262,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/74844262/how-can-i-solve-error-module-numpy-has-no-attribute-float-in-python',
#    'title': 'How can I solve error &quot;module &#39;numpy&#39; has no attribute &#39;float&#39;&quot; in Python?'},
#   {'tags': ['python', 'enums', 'f-string'],
#    'owner': {'account_id': 10991861,
#     'reputation': 6792,
#     'user_id': 8075540,
#     'user_type': 'registered',
#     'profile_image': 'https://i.sstatic.net/0eZhT.jpg?s=256',
#     'display_name': 'Daniel Walker',
#     'link': 'https://stackoverflow.com/users/8075540/daniel-walker'},
#    'is_answered': True,
#    'view_count': 10454,
#    'accepted_answer_id': 72449614,
#    'answer_count': 2,
#    'score': 74,
#    'last_activity_date': 1693593159,
#    'creation_date': 1654006677,
#    'last_edit_date': 1660255156,
#    'question_id': 72449482,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/72449482/f-string-representation-different-than-str',
#    'title': 'f-string representation different than str()'},
#   {'tags': ['python', 'django', 'heroku'],
#    'owner': {'account_id': 16660311,
#     'reputation': 829,
#     'user_id': 12040445,
#     'user_type': 'registered',
#     'profile_image': 'https://i.sstatic.net/ydOnG.jpg?s=256',
#     'display_name': 'SarveshJoshi',
#     'link': 'https://stackoverflow.com/users/12040445/sarveshjoshi'},
#    'is_answered': True,
#    'view_count': 113952,
#    'accepted_answer_id': 72796492,
#    'answer_count': 11,
#    'score': 73,
#    'last_activity_date': 1697317485,
#    'creation_date': 1648843469,
#    'question_id': 71712258,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71712258/error-could-not-build-wheels-for-backports-zoneinfo-which-is-required-to-insta',
#    'title': 'ERROR: Could not build wheels for backports.zoneinfo, which is required to install pyproject.toml-based projects'},
#   {'tags': ['python', 'ipython'],
#    'owner': {'account_id': 3582471,
#     'reputation': 3062,
#     'user_id': 2990344,
#     'user_type': 'registered',
#     'accept_rate': 69,
#     'profile_image': 'https://www.gravatar.com/avatar/4c1cd2713ef55a0a1f94e6682b567adc?s=256&d=identicon&r=PG&f=y&so-version=2',
#     'display_name': 'xdavidliu',
#     'link': 'https://stackoverflow.com/users/2990344/xdavidliu'},
#    'is_answered': True,
#    'view_count': 14270,
#    'accepted_answer_id': 71459528,
#    'answer_count': 3,
#    'score': 72,
#    'last_activity_date': 1714070853,
#    'creation_date': 1644771035,
#    'question_id': 71102876,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71102876/in-ipython-how-do-i-accept-and-use-an-autocomplete-suggestion',
#    'title': 'in ipython how do I accept and use an autocomplete suggestion?'},
#   {'tags': ['python', 'docker', 'flask', 'docker-compose'],
#    'owner': {'account_id': 22335364,
#     'reputation': 914,
#     'user_id': 16556045,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GitmoVYWKb7Xize5hPMshSWNoFyMKSumgrMWNBXBA=k-s256',
#     'display_name': 'KronosHedronos2077',
#     'link': 'https://stackoverflow.com/users/16556045/kronoshedronos2077'},
#    'is_answered': True,
#    'view_count': 85720,
#    'accepted_answer_id': 71219718,
#    'answer_count': 11,
#    'score': 71,
#    'last_activity_date': 1691078711,
#    'creation_date': 1645310480,
#    'last_edit_date': 1663178530,
#    'question_id': 71189819,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71189819/importerror-cannot-import-name-json-from-itsdangerous',
#    'title': 'ImportError: cannot import name &#39;json&#39; from itsdangerous'},
#   {'tags': ['python', 'python-3.x', 'numpy', 'attributeerror'],
#    'owner': {'account_id': 14338919,
#     'reputation': 1305,
#     'user_id': 10357604,
#     'user_type': 'registered',
#     'profile_image': 'https://lh6.googleusercontent.com/-TIlsbL_ZgKQ/AAAAAAAAAAI/AAAAAAAAAAA/APUIFaMkliD8S-L2E1T0gqz6w5NYzXYjoQ/mo/photo.jpg?sz=256',
#     'display_name': 'thestruggleisreal',
#     'link': 'https://stackoverflow.com/users/10357604/thestruggleisreal'},
#    'is_answered': True,
#    'view_count': 200806,
#    'protected_date': 1713218557,
#    'answer_count': 8,
#    'score': 70,
#    'last_activity_date': 1713206172,
#    'creation_date': 1671742425,
#    'last_edit_date': 1692728118,
#    'question_id': 74893742,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/74893742/how-to-solve-attributeerror-module-numpy-has-no-attribute-bool',
#    'title': 'How to solve AttributeError: module &#39;numpy&#39; has no attribute &#39;bool&#39;?'},
#   {'tags': ['python'],
#    'owner': {'account_id': 24835532,
#     'reputation': 691,
#     'user_id': 18714220,
#     'user_type': 'registered',
#     'profile_image': 'https://lh3.googleusercontent.com/a-/AOh14GjpNxl2WQc7w30aQ9y641atIyL2lvv3QmWJaerZC04=k-s256',
#     'display_name': 'Bachir bessei',
#     'link': 'https://stackoverflow.com/users/18714220/bachir-bessei'},
#    'is_answered': True,
#    'view_count': 193977,
#    'protected_date': 1721809033,
#    'answer_count': 19,
#    'score': 69,
#    'last_activity_date': 1735360580,
#    'creation_date': 1649198983,
#    'last_edit_date': 1673098786,
#    'question_id': 71759248,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/71759248/importerror-cannot-import-name-builder-from-google-protobuf-internal',
#    'title': 'ImportError: cannot import name &#39;builder&#39; from &#39;google.protobuf.internal&#39;'},
#   {'tags': ['python',
#     'amazon-web-services',
#     'amazon-s3',
#     'aws-lambda',
#     'boto3'],
#    'owner': {'account_id': 5059080,
#     'reputation': 3047,
#     'user_id': 4061339,
#     'user_type': 'registered',
#     'accept_rate': 70,
#     'profile_image': 'https://i.sstatic.net/HeGDO.png?s=256',
#     'display_name': 'dixhom',
#     'link': 'https://stackoverflow.com/users/4061339/dixhom'},
#    'is_answered': True,
#    'view_count': 112727,
#    'accepted_answer_id': 76422261,
#    'answer_count': 13,
#    'score': 69,
#    'last_activity_date': 1728136822,
#    'creation_date': 1686053443,
#    'question_id': 76414514,
#    'content_license': 'CC BY-SA 4.0',
#    'link': 'https://stackoverflow.com/questions/76414514/cannot-import-name-default-ciphers-from-urllib3-util-ssl-on-aws-lambda-us',
#    'title': '&quot;cannot import name &#39;DEFAULT_CIPHERS&#39; from &#39;urllib3.util.ssl_&#39;&quot; on AWS Lambda using a layer'}]}
